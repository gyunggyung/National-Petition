# %%
import pandas as pd

# %%
df = pd.read_csv("test.csv")
df_t = pd.read_csv("test_num.csv")

# %%
df
# Out:
#         Source Target
# 0           이유    피의자
# 1           이유    피의자
# 2           이유    피의자
# 3           이유    피의자
# 4           이유    피의자
# 5           이유    피의자
# 6           이유    피의자
# 7           이유    피의자
# 8           이유    피의자
# 9           이유    우울증
# 10          이유    우울증
# 11          이유    우울증
# 12          이유    우울증
# 13          이유    우울증
# 14          이유    우울증
# 15          이유    우울증
# 16          이유    우울증
# 17          이유    우울증
# 18          이유     뉴스
# 19          이유     뉴스
# 20          이유     뉴스
# 21          이유     뉴스
# 22          이유     뉴스
# 23          이유     뉴스
# 24          이유     뉴스
# 25          이유     뉴스
# 26          이유     뉴스
# 27          이유     심신
# 28          이유     심신
# 29          이유     심신
# ...        ...    ...
# 3878300     치료     감형
# 3878301     치료     감형
# 3878302     치료     감형
# 3878303     치료     감형
# 3878304     치료     감형
# 3878305     치료     감형
# 3878306     치료     감형
# 3878307     치료     감형
# 3878308     치료     감형
# ...

# %%
df_t[:50]
# Out:
#             Pair   Num
# 0   ('심신', '미약')  5274
# 1   ('미약', '심신')  5274
# 2   ('심신', '사건')  3783
# 3   ('사건', '심신')  3783
# 4    ('관', '비서')  3437
# 5    ('비서', '관')  3437
# 6   ('미약', '사건')  3279
# 7   ('사건', '미약')  3279
# 8   ('청원', '국민')  2448
# 9   ('국민', '청원')  2448
# 10  ('심신', '경우')  2430
# 11  ('경우', '심신')  2430
# 12   ('사건', '관')  2286
# 13   ('관', '사건')  2286
# 14   ('관', '정혜')  2270
# 15    ('관', '승')  2270
# 16   ('정혜', '관')  2270
# 17    ('승', '관')  2270
# 18  ('비서', '정혜')  2143
# 19   ('비서', '승')  2143
# 20  ('정혜', '비서')  2143
# 21   ('승', '비서')  2143
# 22  ('미약', '경우')  2106
# 23  ('경우', '미약')  2106
# 24  ('난민', '신청')  2060
# 25  ('신청', '난민')  2060
# 26  ('사건', '경우')  2041
# 27  ('경우', '사건')  2041
# 28  ('사건', '비서')  2033
# 29  ('비서', '사건')  2033
# 30   ('심신', '관')  2025
# 31  ('심신', '판단')  2025
# 32   ('관', '심신')  2025
# 33  ('판단', '심신')  2025
# 34  ('사건', '청원')  2019
# 35  ('청원', '사건')  2019
# 36   ('관', '청원')  2016
# 37   ('청원', '관')  2016
# 38  ('심신', '센터')  1890
# ...

# %%
df1 = df[df["Source"]=="심신"]
df1
# Out:
#         Source Target
# 900         심신     이유
# 901         심신     이유
# 902         심신     이유
# 903         심신     이유
# 904         심신     이유
# 905         심신     이유
# 906         심신     이유
# 907         심신     이유
# 908         심신     이유
# 909         심신    피의자
# 910         심신    피의자
# 911         심신    피의자
# 912         심신    피의자
# 913         심신    피의자
# 914         심신    피의자
# 915         심신    피의자
# 916         심신    피의자
# 917         심신    피의자
# 918         심신    우울증
# 919         심신    우울증
# 920         심신    우울증
# 921         심신    우울증
# 922         심신    우울증
# 923         심신    우울증
# 924         심신    우울증
# 925         심신    우울증
# 926         심신    우울증
# 927         심신     뉴스
# 928         심신     뉴스
# 929         심신     뉴스
# ...        ...    ...
# 3653247     심신     치료
# 3653248     심신     치료
# 3653249     심신     치료
# 3653250     심신     치료
# 3653251     심신     치료
# 3653252     심신     치료
# 3653253     심신     치료
# 3653254     심신     치료
# 3653255     심신     치료
# ...

# %%
df1.to_csv("output/살인자.csv",index=False)

# %%
df2 = df[df["Source"]=="정의"]
df2
# Out:
#        Source Target
# 7806       정의     수사
# 7807       정의     수사
# 7808       정의     수사
# 7809       정의     수사
# 7810       정의     의혹
# 7811       정의     의혹
# 7812       정의     의혹
# 7813       정의     의혹
# 7814       정의     소환
# 7815       정의     소환
# 7816       정의     소환
# 7817       정의     소환
# 7818       정의     의원
# 7819       정의     의원
# 7820       정의     의원
# 7821       정의     의원
# 7822       정의     사법
# 7823       정의     사법
# 7824       정의     사법
# 7825       정의     사법
# 7826       정의      명
# 7827       정의      명
# 7828       정의      명
# 7829       정의      명
# 7830       정의     독점
# 7831       정의     독점
# 7832       정의     독점
# 7833       정의     독점
# 7834       정의   강원랜드
# 7835       정의   강원랜드
# ...       ...    ...
# 476130     정의     특수
# 476131     정의     활동
# 476132     정의     활동
# 476133     정의   대한민국
# 476134     정의     바로
# 476135     정의     최근
# 476136     정의     불법
# 476137     정의     적법
# 476138     정의    청와대
# 476139     정의     업무
# 476140     정의     추진
# ...

# %%
df2.to_csv("의혹.csv",index=False)

# %%
df3 = df[df["Source"]=="이재명"]
df3
# Out:
#        Source Target
# 3496      이재명     그것
# 3497      이재명   알고싶다
# 3498      이재명     에서
# 3499      이재명     내용
# 3500      이재명    은수미
# 3501      이재명   성남시장
# 3502      이재명     조폭
# 3503      이재명     관련
# 3504      이재명     사실
# 3505      이재명     만약
# 3506      이재명      법
# 3507      이재명     엄히
# 3508      이재명     처벌
# 24848     이재명     조폭
# 24849     이재명     조폭
# 24850     이재명     조폭
# 24851     이재명     조폭
# 24852     이재명     조폭
# 24853     이재명     조폭
# 24854     이재명    은수미
# 24855     이재명    은수미
# 24856     이재명    은수미
# 24857     이재명    은수미
# 24858     이재명     연관
# 24859     이재명     연관
# 24860     이재명     연관
# 24861     이재명     연관
# 24862     이재명      설
# 24863     이재명      설
# 24864     이재명      설
# ...       ...    ...
# 24935     이재명     의심
# 24936     이재명     사람
# 24937     이재명     사람
# 24938     이재명     상식
# 24939     이재명     상식
# 24940     이재명   민주주의
# 24941     이재명   민주주의
# 24942     이재명   대한민국
# 24943     이재명   대한민국
# 24944     이재명     정치
# 24945     이재명     정치
# ...

# %%
df3.to_csv("이재명.csv",index=False)

# %%
df4 = df[df["Source"]=="문재인"]
df4
# Out:
#        Source Target
# 5816      문재인     언론
# 5817      문재인     언론
# 5818      문재인     계정
# 5819      문재인     계정
# 5820      문재인     수사
# 5821      문재인     수사
# 5822      문재인    법무부
# 5823      문재인    법무부
# 5824      문재인    대통령
# 5825      문재인    대통령
# 5826      문재인      꼭
# 5827      문재인      꼭
# 5828      문재인     연일
# 5829      문재인     메인
# 5830      문재인     장식
# 5831      문재인     일명
# 5832      문재인    혜경궁
# 5833      문재인     김씨
# 5834      문재인    트위터
# 5835      문재인     과정
# 5836      문재인     미국
# 5837      문재인     공조
# 5838      문재인     신청
# 5839      문재인     한국
# 5840      문재인     보도
# 5841      문재인     무슨
# 5842      문재인      고
# 5843      문재인    노무현
# 5844      문재인      전
# 5845      문재인      현
# ...       ...    ...
# 474953    문재인     집중
# 474954    문재인     집중
# 474955    문재인     사건
# 474956    문재인     사건
# 474957    문재인     사건
# 474958    문재인    대통령
# 474959    문재인    대통령
# 474960    문재인     부대
# 474961    문재인     부대
# 474962    문재인     수구
# 474963    문재인     수구
# ...

# %%
df1
# Out:
#        Source Target
# 122214    살인자     뉴스
# 122215    살인자     뉴스
# 122216    살인자     뉴스
# 122217    살인자     뉴스
# 122218    살인자     뉴스
# 122219    살인자     뉴스
# 122220    살인자     뉴스
# 122221    살인자     뉴스
# 122222    살인자     뉴스
# 122223    살인자     뉴스
# 122224    살인자     뉴스
# 122225    살인자     뉴스
# 122226    살인자     뉴스
# 122227    살인자     뉴스
# 122228    살인자     뉴스
# 122229    살인자     뉴스
# 122230    살인자     뉴스
# 122231    살인자     뉴스
# 122232    살인자     뉴스
# 122233    살인자     뉴스
# 122234    살인자     뉴스
# 122235    살인자     뉴스
# 122236    살인자     뉴스
# 122237    살인자     뉴스
# 122238    살인자     뉴스
# 122239    살인자     뉴스
# 122240    살인자     뉴스
# 122241    살인자     뉴스
# 122242    살인자     뉴스
# 122243    살인자     뉴스
# ...       ...    ...
# 122821    살인자     자신
# 122822    살인자     자신
# 122823    살인자     증거
# 122824    살인자     증거
# 122825    살인자     증거
# 122826    살인자     증거
# 122827    살인자     증거
# 122828    살인자     증거
# 122829    살인자     증거
# 122830    살인자     퍼트
# 122831    살인자     퍼트
# ...

# %%
df4.to_csv("문재인.csv",index=False)

# %%
df1 = df1.append(df4)
df1
# Out:
#        Source Target
# 122214    살인자     뉴스
# 122215    살인자     뉴스
# 122216    살인자     뉴스
# 122217    살인자     뉴스
# 122218    살인자     뉴스
# 122219    살인자     뉴스
# 122220    살인자     뉴스
# 122221    살인자     뉴스
# 122222    살인자     뉴스
# 122223    살인자     뉴스
# 122224    살인자     뉴스
# 122225    살인자     뉴스
# 122226    살인자     뉴스
# 122227    살인자     뉴스
# 122228    살인자     뉴스
# 122229    살인자     뉴스
# 122230    살인자     뉴스
# 122231    살인자     뉴스
# 122232    살인자     뉴스
# 122233    살인자     뉴스
# 122234    살인자     뉴스
# 122235    살인자     뉴스
# 122236    살인자     뉴스
# 122237    살인자     뉴스
# 122238    살인자     뉴스
# 122239    살인자     뉴스
# 122240    살인자     뉴스
# 122241    살인자     뉴스
# 122242    살인자     뉴스
# 122243    살인자     뉴스
# ...       ...    ...
# 474953    문재인     집중
# 474954    문재인     집중
# 474955    문재인     사건
# 474956    문재인     사건
# 474957    문재인     사건
# 474958    문재인    대통령
# 474959    문재인    대통령
# 474960    문재인     부대
# 474961    문재인     부대
# 474962    문재인     수구
# 474963    문재인     수구
# ...

# %%
df1.to_csv("살인자_문재인.csv",index=False)
