# %%
import pandas as pd

# %%
df = pd.read_csv("participants.csv")
df
# Out:
#         육아/교육   보건복지   정치개혁    일자리     기타  외교/통일/국방  반려동물  교통/건축/국토     행정  \
# 0       24569  23170  57865  21593  45658     25277  3752     26517  19038
# 1       20681  20910  47902  18917  37708     22679  3623     24057  16056
# 2       18097  18493  42027  16033  31667     20049  3465     21337  13591
# 3       15861  16369  37885  13407  27067     17782  3318     18992  11553
# 4       14058  14568  34584  11356  23494     15849  3169     17151   9972
# 5       12610  13047  31796   9807  20694     14245  3027     15654   8666
# 6       11445  11807  29350   8523  18476     12950  2894     14459   7660
# 7       10510  10789  27251   7515  16713     11775  2770     13353   6877
# 8        9682   9968  25420   6704  15193     10833  2658     12445   6226
# 9        8999   9233  23696   6055  13964     10041  2541     11646   5727
# 10       8466   8578  22162   5493  12886      9321  2435     10970   5291
# ...

# %%
names = list(df)

# %%
df[names[0]][0]
# Out:
# 24569

# %%
df[names[0]][0] * df[names[0]][0] / 10000
# Out:
# 60363.5761

# %%
2.9367
# Out:
# 2.9367

# %%
df[names[1]][0] * df[names[1]][0] / 10000
# Out:
# 53684.89

# %%
from sklearn import preprocessing

x = df.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
dfs = pd.DataFrame(x_scaled,  columns= names)
dfs
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
#            육아/교육      보건복지      정치개혁       일자리        기타  외교/통일/국방      반려동물  \
# 0       1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1       0.841745  0.902460  0.827823  0.876071  0.825879  0.897215  0.965618
# 2       0.736568  0.798144  0.726294  0.742509  0.693570  0.793163  0.923507
# 3       0.645555  0.706474  0.654714  0.620896  0.592821  0.703474  0.884328
# 4       0.572167  0.628744  0.597667  0.525911  0.514565  0.626998  0.844616
# 5       0.513229  0.563099  0.549486  0.454175  0.453239  0.563539  0.806770
# 6       0.465809  0.509581  0.507215  0.394711  0.404661  0.512304  0.771322
# 7       0.427752  0.465645  0.470941  0.348029  0.366048  0.465817  0.738273
# ...

# %%
dfs[:100]
# Out:
#        육아/교육      보건복지      정치개혁       일자리        기타  외교/통일/국방      반려동물  \
# 0   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1   0.841745  0.902460  0.827823  0.876071  0.825879  0.897215  0.965618
# 2   0.736568  0.798144  0.726294  0.742509  0.693570  0.793163  0.923507
# 3   0.645555  0.706474  0.654714  0.620896  0.592821  0.703474  0.884328
# 4   0.572167  0.628744  0.597667  0.525911  0.514565  0.626998  0.844616
# 5   0.513229  0.563099  0.549486  0.454175  0.453239  0.563539  0.806770
# 6   0.465809  0.509581  0.507215  0.394711  0.404661  0.512304  0.771322
# 7   0.427752  0.465645  0.470941  0.348029  0.366048  0.465817  0.738273
# 8   0.394049  0.430211  0.439298  0.310471  0.332757  0.428549  0.708422
# 9   0.366249  0.398489  0.409505  0.280415  0.305839  0.397215  0.677239
# 10  0.344554  0.370220  0.382995  0.254388  0.282229  0.368729  0.648987
# 11  0.325952  0.347734  0.360391  0.232992  0.261707  0.343963  0.618870
# ...

# %%
import matplotlib as mpl           # 그래프를 그리는 모듈
import matplotlib.pyplot as plt    # 그래프를 그리는 모듈
# 한글 폰트 설정
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

plt.figure(); dfs[:10].plot();

# %%
dfs[:10]
# Out:
#       육아/교육      보건복지      정치개혁       일자리        기타  외교/통일/국방      반려동물  \
# 0  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  0.841745  0.902460  0.827823  0.876071  0.825879  0.897215  0.965618
# 2  0.736568  0.798144  0.726294  0.742509  0.693570  0.793163  0.923507
# 3  0.645555  0.706474  0.654714  0.620896  0.592821  0.703474  0.884328
# 4  0.572167  0.628744  0.597667  0.525911  0.514565  0.626998  0.844616
# 5  0.513229  0.563099  0.549486  0.454175  0.453239  0.563539  0.806770
# 6  0.465809  0.509581  0.507215  0.394711  0.404661  0.512304  0.771322
# 7  0.427752  0.465645  0.470941  0.348029  0.366048  0.465817  0.738273
# 8  0.394049  0.430211  0.439298  0.310471  0.332757  0.428549  0.708422
# 9  0.366249  0.398489  0.409505  0.280415  0.305839  0.397215  0.677239
#
#    교통/건축/국토        행정      농산어촌  저출산/고령화대책     경제민주화  문화/예술/체육/언론    인권/성평등  \
# 0  1.000000  1.000000  1.000000   1.000000  1.000000     1.000000  1.000000
# ...

# %%
dfs2= dfs[["정치개혁","미래","육아/교육","반려동물","외교/통일/국방","기타","교통/건축/국토","일자리","all"]]
dfs2
# Out:
#             정치개혁        미래     육아/교육      반려동물  외교/통일/국방        기타  교통/건축/국토  \
# 0       1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1       0.827823  0.831464  0.841745  0.965618  0.897215  0.825879  0.907226
# 2       0.726294  0.715150  0.736568  0.923507  0.793163  0.693570  0.804646
# 3       0.654714  0.618539  0.645555  0.884328  0.703474  0.592821  0.716209
# 4       0.597667  0.543291  0.572167  0.844616  0.626998  0.514565  0.646779
# 5       0.549486  0.484482  0.513229  0.806770  0.563539  0.453239  0.590323
# 6       0.507215  0.437659  0.465809  0.771322  0.512304  0.404661  0.545256
# 7       0.470941  0.393626  0.427752  0.738273  0.465817  0.366048  0.503545
# 8       0.439298  0.359682  0.394049  0.708422  0.428549  0.332757  0.469302
# 9       0.409505  0.329061  0.366249  0.677239  0.397215  0.305839  0.439169
# 10      0.382995  0.304018  0.344554  0.648987  0.368729  0.282229  0.413675
# ...

# %%
import platform

# %%
if platform.system() == 'Darwin': 
    font_url = "/Library/Fonts/AppleGothic.ttf"
elif platform.system() == 'Windows': 
    font_url = 'C:/Windows/Fonts/malgun.ttf'
elif platform.system() == 'Linux': 
    font_url = "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"

# %%
import matplotlib as mpl           # 그래프를 그리는 모듈
import matplotlib.pyplot as plt    # 그래프를 그리는 모듈
# 한글 폰트 설정
font_name = mpl.font_manager.FontProperties(fname=font_url).get_name()
mpl.rc('font', family=font_name)

plt.figure(); dfs2[:10].plot();

# %%
dfs3= dfs[["인권/성평등","안전/환경","문화/예술/체육/언론","저출산/고령화대책","보건복지","성장동력","행정","경제민주화","농산어촌"]]
dfs3
# Out:
#           인권/성평등     안전/환경  문화/예술/체육/언론  저출산/고령화대책      보건복지      성장동력  \
# 0       1.000000  1.000000     1.000000   1.000000  1.000000  1.000000
# 1       0.833772  0.831735     0.894929   0.882301  0.902460  0.846491
# 2       0.743892  0.719937     0.782126   0.750807  0.798144  0.698380
# 3       0.672963  0.631337     0.683136   0.638392  0.706474  0.582227
# 4       0.613054  0.562876     0.605041   0.543587  0.628744  0.495258
# 5       0.562438  0.508162     0.540346   0.462284  0.563099  0.420108
# 6       0.517331  0.464378     0.488755   0.401233  0.509581  0.362323
# 7       0.477704  0.428773     0.447376   0.358086  0.465645  0.323070
# 8       0.444767  0.397154     0.413671   0.319343  0.430211  0.289654
# 9       0.417734  0.370451     0.382209   0.289698  0.398489  0.257551
# 10      0.391003  0.345190     0.354052   0.266804  0.370220  0.230410
# 11      0.368904  0.325635     0.332153   0.243029  0.347734  0.209981
# ...

# %%
import matplotlib as mpl           # 그래프를 그리는 모듈
import matplotlib.pyplot as plt    # 그래프를 그리는 모듈
# 한글 폰트 설정
font_name = mpl.font_manager.FontProperties(fname=font_url).get_name()
mpl.rc('font', family=font_name)

i = 5
plt.figure(); dfs3[:i].plot(); plt.figure(); dfs2[:i].plot();

# %%
dfs4= dfs[["농산어촌","반려동물","인권/성평등","일자리","정치개혁","all"]]
dfs4
# Out:
#             농산어촌      반려동물    인권/성평등       일자리      정치개혁       all
# 0       1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1       0.794694  0.965618  0.833772  0.876071  0.827823  0.856124
# 2       0.636101  0.923507  0.743892  0.742509  0.726294  0.745355
# 3       0.516148  0.884328  0.672963  0.620896  0.654714  0.655376
# 4       0.417532  0.844616  0.613054  0.525911  0.597667  0.583147
# 5       0.354095  0.806770  0.562438  0.454175  0.549486  0.524341
# 6       0.302768  0.771322  0.517331  0.394711  0.507215  0.476257
# 7       0.268166  0.738273  0.477704  0.348029  0.470941  0.436030
# 8       0.242215  0.708422  0.444767  0.310471  0.439298  0.402333
# 9       0.225490  0.677239  0.417734  0.280415  0.409505  0.373208
# 10      0.198962  0.648987  0.391003  0.254388  0.382995  0.347541
# 11      0.182238  0.618870  0.368904  0.232992  0.360391  0.325668
# 12      0.164360  0.593550  0.349227  0.215070  0.339877  0.306816
# ...

# %%
i = 10
plt.figure(); dfs4[:i].plot(); plt.figure(); dfs[:i].plot();

plt.figure(); dfs3[:i].plot(); plt.figure(); dfs2[:i].plot();

# %%
i = 30
plt.figure(); dfs4[:i].plot(); plt.figure(); dfs[:i].plot();

plt.figure(); dfs3[:i].plot(); plt.figure(); dfs2[:i].plot();

# %%
i = 50
plt.figure(); dfs4[:i].plot(); plt.figure(); dfs[:i].plot();

plt.figure(); dfs3[:i].plot(); plt.figure(); dfs2[:i].plot();

# %%
i = 100
plt.figure(); dfs4[:i].plot(); plt.figure(); dfs[:i].plot();

plt.figure(); dfs3[:i].plot(); plt.figure(); dfs2[:i].plot();
