# %%
import re
import pandas as pd

# %%
df = pd.read_csv("../petition_data_all_no.csv")
df
# Out:
#            num     category  start-days    end-days          person progress  \
# 0           21        안전/환경  2017-08-19  2017-11-17     kakao - ***    청원종료
# 1           22           기타  2017-08-19  2017-11-17     kakao - ***    청원종료
# 2           23           미래  2017-08-19  2017-09-03     kakao - ***    청원종료
# 3           24          일자리  2017-08-19  2017-08-26     kakao - ***    청원종료
# 4           25           미래  2017-08-19  2017-09-03     kakao - ***    청원종료
# 5           26         보건복지  2017-08-19  2017-08-26     naver - ***    청원종료
# 6           27         정치개혁  2017-08-19  2017-09-18     naver - ***    청원종료
# 7           28        경제민주화  2017-08-19  2017-08-26     naver - ***    청원종료
# 8           29           미래  2017-08-19  2017-09-18     naver - ***    청원종료
# 9           30          일자리  2017-08-19  2017-11-17     kakao - ***    청원종료
# 10          31         보건복지  2017-08-19  2017-11-17   twitter - ***    청원종료
# 11          32        경제민주화  2017-08-19  2017-09-03     naver - ***    청원종료
# 12          33       인권/성평등  2017-08-19  2017-11-17     naver - ***    청원종료
# 13          34           기타  2017-08-19  2017-09-18     naver - ***    청원종료
# 14          35     외교/통일/국방  2017-08-19  2017-08-26     kakao - ***    청원종료
# 15          36       인권/성평등  2017-08-19  2017-08-26     naver - ***    청원종료
# 16          37           기타  2017-08-19  2017-09-18  facebook - ***    청원종료
# 17          38     외교/통일/국방  2017-08-19  2017-08-26     kakao - ***    청원종료
# 18          40     외교/통일/국방  2017-08-19  2017-09-18     naver - ***    청원종료
# 19          41     외교/통일/국방  2017-08-19  2017-09-18     naver - ***    청원종료
# 20          42        육아/교육  2017-08-19  2017-09-18     naver - ***    청원종료
# 21          43        육아/교육  2017-08-19  2017-09-18     naver - ***    청원종료
# 22          44        육아/교육  2017-08-19  2017-09-18  facebook - ***    청원종료
# 23          45        육아/교육  2017-08-19  2017-11-17  facebook - ***    청원종료
# 24          46        육아/교육  2017-08-19  2017-09-18     naver - ***    청원종료
# 25          47     외교/통일/국방  2017-08-19  2017-09-18  facebook - ***    청원종료
# 26          48  문화/예술/체육/언론  2017-08-19  2017-09-18  facebook - ***    청원종료
# 27          49          일자리  2017-08-19  2017-11-17     naver - ***    청원종료
# 28          50          일자리  2017-08-19  2017-10-18     naver - ***    청원종료
# 29          51        경제민주화  2017-08-19  2017-11-17     naver - ***    청원종료
# ...        ...          ...         ...         ...             ...      ...
# 371200  484310       인권/성평등  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371201  484311     교통/건축/국토  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371202  484312           미래  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371203  484313        안전/환경  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371204  484314        안전/환경  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371205  484315         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371206  484316       인권/성평등  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371207  484317     외교/통일/국방  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371208  484318           기타  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371209  484319     외교/통일/국방  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371210  484320         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371211  484321          일자리  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371212  484322    저출산/고령화대책  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371213  484323       인권/성평등  2019-01-01  2019-01-31  facebook - ***   청원진행중
# 371214  484324     교통/건축/국토  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371215  484325         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371216  484326         정치개혁  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371217  484327           미래  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371218  484328         정치개혁  2019-01-01  2019-01-31  facebook - ***   청원진행중
# 371219  484329         정치개혁  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371220  484330           행정  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371221  484331         정치개혁  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371222  484332       인권/성평등  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371223  484333  문화/예술/체육/언론  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371224  484334          일자리  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371225  484335           미래  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371226  484336         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371227  484337           기타  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371228  484338         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371229  484339         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
#
#                                                     title               count  \
# 0                                     스텔라 데이지호에 대한 제안입니다.       참여인원 : [ 9명 ]
# 1                                          비리제보처를 만들어주세요.      참여인원 : [ 17명 ]
# 2                                                제2의 개성공단       참여인원 : [ 0명 ]
# 3                                공공기관 무조건적인 정규직전환을 반대합니다.      참여인원 : [ 53명 ]
# 4                                                제2의 개성공단       참여인원 : [ 0명 ]
# 5       보건복지부 부령 제339호중 “특수의료장비 운영에 관한 규칙” 중  불합리한 행정제...       참여인원 : [ 2명 ]
# 6                                       김이수 헌재소장 임명 재고 건의       참여인원 : [ 1명 ]
# 7                                           소액주주를 보호해주십시오   참여인원 : [ 2,137명 ]
# 8                                 문재인 정부는 왜 공무원개혁엔 무관심한가?       참여인원 : [ 3명 ]
# 9                                     A/S 기사들도 관심을 가져주십시요       참여인원 : [ 1명 ]
# 10                     <담배 제조 및 매매금지 법안>을 제정해 주시길 부탁드립니다.       참여인원 : [ 0명 ]
# 11                                 소액주주 보호를 위해 조사요청 드립니다.      참여인원 : [ 30명 ]
# 12                              납득할 수 있는 장애 재판정을 받고 싶습니다.      참여인원 : [ 15명 ]
# 13      『국가유공자 등 예우 및 지원에 관한법률』상「6.25전몰군경 자녀수당」의 불합리한 ...     참여인원 : [ 679명 ]
# 14                            문재인정부는 신한국형 페리프로세스가 작성했습니다.       참여인원 : [ 0명 ]
# 15          한국채식인구 100만명. 학교 급식 및 군대에서 현미채식 선택권을 보장해주십시오!       참여인원 : [ 1명 ]
# 16                                  황우석박사님 연구재개 허용 촉구합니다.     참여인원 : [ 415명 ]
# 17                                 한중관계 사드 갈등 해소방법 찾았습니다.       참여인원 : [ 0명 ]
# 18                           국가유공자등 예우및 지우너에 관한 법률 시행령 개정     참여인원 : [ 218명 ]
# 19                           국가유공자등 예우및 지우너에 관한 법률 시행령 개정     참여인원 : [ 227명 ]
# 20                                   기간제 교사의 정규직화를 반대합니다.     참여인원 : [ 173명 ]
# 21                                   기간제 교사의 정규직화를 반대합니다.  참여인원 : [ 11,293명 ]
# 22              해외 수학여행 및 학생 프로그램 참가시 시간외 근무수당을 지급해 주십시오.       참여인원 : [ 9명 ]
# 23                                  초등학교 교사 임용 시험 관련 해결방안       참여인원 : [ 0명 ]
# 24                                    기간제교사의 정규직화를 반대합니다.   참여인원 : [ 1,933명 ]
# 25                              국가유공자예우및 지우너에 관한 법률시행령 개정     참여인원 : [ 215명 ]
# 26                 3.1 운동 100주년 기념사업 준비, 더이상 지체해서는 안 됩니다.      참여인원 : [ 12명 ]
# 27                              공정한사회 절차가 바른사회가 되기를 원합니다.      참여인원 : [ 27명 ]
# 28                                 치과위생사 국가고시 날짜 변경 억울합니다   참여인원 : [ 1,251명 ]
# 29                                     중국기업 국내 상장을 반대합니다.      참여인원 : [ 74명 ]
# ...                                                   ...                 ...
# 371200         관리자님 (안동경찰의 민간인사찰) 게시글 삭제와 차단에 관하여 말씀 드립니다       참여인원 : [ 1명 ]
# 371201                    건설/인테리어 직종 근무시간 및 휴식보장에 힘을 써주세요       참여인원 : [ 2명 ]
# 371202                                               줄기세포       참여인원 : [ 0명 ]
# 371203                                      정신병자의 계속되는 범죄       참여인원 : [ 1명 ]
# 371204       최근 네이버계정이 중화인민공화국 또는 몽골에서 해킹시도가 두 번이나 있었습니다.       참여인원 : [ 0명 ]
# 371205                   [개헌건의]공정한 판결을 위해 판사도 선거로 뽑아야합니다.       참여인원 : [ 1명 ]
# 371206                                      저의 억울함을 들어주세요       참여인원 : [ 2명 ]
# 371207                     병영 내 휴대폰 사용에 대해 다시 한번 생각 해 주세요       참여인원 : [ 2명 ]
# 371208         '서기, 양력 VS 단기, 음력' → '만 나이 VS 세는 나이, 연 나이'       참여인원 : [ 3명 ]
# 371209                               북한은 핵보유국, 우리는 재앙 보유국       참여인원 : [ 2명 ]
# 371210                                      적자국채발행지시 카톡공개       참여인원 : [ 0명 ]
# 371211                               누구를 위한 블라인드? 장애인 빼고?       참여인원 : [ 0명 ]
# 371212                     국민연금 개선안 - 내 연금이 부모님께 가도록 해주세요       참여인원 : [ 0명 ]
# 371213                     반부폐 경찰공무원  김민영의 갑질 억울한 호소문 입니다       참여인원 : [ 0명 ]
# 371214                             아파트 불법, 부당행위 와 일부지방공무원       참여인원 : [ 1명 ]
# 371215                          투표 한표 저항권을 국민에게 부여해야 합니다.       참여인원 : [ 0명 ]
# 371216           [국민감사] 서울고검 박승환 을 직권남용, 국헌문란죄로 고발합니다. 32       참여인원 : [ 0명 ]
# 371217                            나라를 더 망치기전에 빨리 탄핵해야합니다.       참여인원 : [ 3명 ]
# 371218                                              페미공화국       참여인원 : [ 1명 ]
# 371219           [국민감사] 서울고검 박승환 을 직권남용, 국헌문란죄로 고발합니다. 33       참여인원 : [ 0명 ]
# 371220                                      공무원연금법에 대한 제언       참여인원 : [ 1명 ]
# 371221           [국민감사] 서울고검 박승환 을 직권남용, 국헌문란죄로 고발합니다. 34       참여인원 : [ 0명 ]
# 371222                              공정하고 정의로운 나라가 이런 겁니까!       참여인원 : [ 1명 ]
# 371223          새해소원은 정의롭게 한게임도박장 철저히 밝혀 정부 연관자들도 조사하는겁니다       참여인원 : [ 1명 ]
# 371224                                          자진퇴사 실업급여       참여인원 : [ 1명 ]
# 371225  20대-영남-자영업자 "경제정책 잘못"... 전연령대 과반 부정 평가 / 2019년...       참여인원 : [ 1명 ]
# 371226                                 국회의원  면책특권을  없애버리자       참여인원 : [ 0명 ]
# 371227                            빠른년생들도 친구들과 함께 하고 싶습니다.       참여인원 : [ 1명 ]
# 371228                                 국회의원  면책특권을  없애버리자       참여인원 : [ 2명 ]
# 371229                                     이해찬 대표님 사퇴하시죠?       참여인원 : [ 0명 ]
#
#                                         petition_overview
# 0       \n\t\t\t\t\t\t\t\t\t\t\t스텔라 데이지호에 대한 제안입니다. \n...
# 1       \n\t\t\t\t\t\t\t\t\t\t\t현 정부에 국민들이 가장 원하는 것은 부...
# 2       \n\t\t\t\t\t\t\t\t\t\t\t만일 하시는 대통령님 및 각 부처 장관님...
# 3       \n\t\t\t\t\t\t\t\t\t\t\t현정부에서 정규직 일자리를 늘리는 것에 ...
# 4       \n\t\t\t\t\t\t\t\t\t\t\t만일 하시는 대통령님 및 각 부처 장관님...
# 5       \n\t\t\t\t\t\t\t\t\t\t\t청원인  왕 기 운 \n\t\t\t\t\...
# 6       \n\t\t\t\t\t\t\t\t\t\t\t문 대통령님께 묻습니다 (2017. 8....
# 7       \n\t\t\t\t\t\t\t\t\t\t\t**  존경하옵는 문재인대통령님께  \n...
# 8       \n\t\t\t\t\t\t\t\t\t\t\t살충제 계란 사건으로 국민들을 불안케 하...
# 9       \n\t\t\t\t\t\t\t\t\t\t\t안녕하세요. 저는 LG전자 서비스센터에서...
# 10      \n\t\t\t\t\t\t\t\t\t\t\t안녕하세요 대통령님 \n\t\t\t\t\...
# 11      \n\t\t\t\t\t\t\t\t\t\t\t존경하는 대통령님께,  \n\n\t\t\...
# 12      \n\t\t\t\t\t\t\t\t\t\t\t안녕하십니까? 저는 경직형 양마비 뇌병변...
# 13      \n\t\t\t\t\t\t\t\t\t\t\t(현황) \n\t\t\t\t\t\t\t\...
# 14      \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님 신한국형 페리프로세스 로...
# 15      \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님과 각 정부 인사분들께 마...
# 16      \n\t\t\t\t\t\t\t\t\t\t\t국민의 70% 이상이 황우석박사님을 응원...
# 17      \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님 한중관계 사드 갈등 해소...
# 18      \n\t\t\t\t\t\t\t\t\t\t\t지금부터 67년전 1950년 6.25전쟁...
# 19      \n\t\t\t\t\t\t\t\t\t\t\t지금부터 67년전 1950년 6.25전쟁...
# 20      \n\t\t\t\t\t\t\t\t\t\t\t대통령님, 안녕하세요. 저는 임용을 준비...
# 21      \n\t\t\t\t\t\t\t\t\t\t\t대통령님, 안녕하세요. 저는 임용을 준비...
# 22      \n\t\t\t\t\t\t\t\t\t\t\t광주 과학고등학교에서 학생들을 인솔하여 ...
# 23      \n\t\t\t\t\t\t\t\t\t\t\t초등학교 교사 임용 시험을 수능 시험 처...
# 24      \n\t\t\t\t\t\t\t\t\t\t\t대통령님, 안녕하세요. 저는 임용을 준비...
# 25      \n\t\t\t\t\t\t\t\t\t\t\t지금부터 67년전 1950년 6.25전쟁...
# 26      \n\t\t\t\t\t\t\t\t\t\t\t존경하는 문재인 대통령님, 앞으로 1년 ...
# 27      \n\t\t\t\t\t\t\t\t\t\t\t문재인대통령과 교육부장관님! \n\t\t...
# 28      \n\t\t\t\t\t\t\t\t\t\t\t안녕하십니까? 대통령님 간단하게 제소개 ...
# 29      \n\t\t\t\t\t\t\t\t\t\t\t국내 증시에 상장한 중국 기업들의 현황과...
# ...                                                   ...
# 371200  \n\t\t\t\t\t\t\t\t\t\t\t♣️관리자님 안녕하세요  \n\t\t\t...
# 371201  \n\t\t\t\t\t\t\t\t\t\t\t안녕하세요. 저는 건축/인테리어 업종을 ...
# 371202  \n\t\t\t\t\t\t\t\t\t\t\t줄기세포연구합법화해주세요.전근이완증이라는...
# 371203  \n\t\t\t\t\t\t\t\t\t\t\t누가 새해 첫날부터 이런 글을 쓰고 싶을...
# 371204  \n\t\t\t\t\t\t\t\t\t\t\t인터넷 해킹방지법 만들어주세요! \n\t...
# 371205  \n\t\t\t\t\t\t\t\t\t\t\t결론부터 말하겠습니다. 판사도 투표로 뽑...
# 371206  \n\t\t\t\t\t\t\t\t\t\t\t안녕하세여 저는 일본에서 살다가 2012...
# 371207  \n\t\t\t\t\t\t\t\t\t\t\t올해  2월부터 국방부는 병사들의 일과 ...
# 371208  \n\t\t\t\t\t\t\t\t\t\t\t한국에서는 1962년부터 만 나이를 쓰도...
# 371209  \n\t\t\t\t\t\t\t\t\t\t\t굴욕외교의 결정판 !! \n\t\t\t\...
# 371210  \n\t\t\t\t\t\t\t\t\t\t\t기재부 신재민. 사무관이 적자국채발향지시...
# 371211  \n\t\t\t\t\t\t\t\t\t\t\t제 소개 먼저 하겠습니다. 저는 2014...
# 371212  \n\t\t\t\t\t\t\t\t\t\t\t국민연금 고갈에 대한 이슈가 여전한테 현...
# 371213  \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님 안녕  하십니까.?.. ...
# 371214  \n\t\t\t\t\t\t\t\t\t\t\t청와대 국민청원 \n\n\t\t\t\t\...
# 371215  \n\t\t\t\t\t\t\t\t\t\t\t국민이 자신의  한 표를 투표장에서 행사...
# 371216  \n\t\t\t\t\t\t\t\t\t\t\t사법농단 척결을 위한 후원금 모금안내 1...
# 371217  \n\t\t\t\t\t\t\t\t\t\t\t나라를 더 망치기전에 빨리 탄핵해야합니다...
# 371218  \n\t\t\t\t\t\t\t\t\t\t\t세상ㅇㅣ 이렇게 더럽게 타락한 이유가 멀...
# 371219  \n\t\t\t\t\t\t\t\t\t\t\t사법농단 척결을 위한 후원금 모금안내 1...
# 371220  \n\t\t\t\t\t\t\t\t\t\t\t공무원연금법에 대한 제언 \n\n\t\t...
# 371221  \n\t\t\t\t\t\t\t\t\t\t\t사법농단 척결을 위한 후원금 모금안내 1...
# 371222  \n\t\t\t\t\t\t\t\t\t\t\t돈 없고 힘없는 농민은 언제까지 이렇게 ...
# 371223  \n\t\t\t\t\t\t\t\t\t\t\t지금 이순간에도 대놓고 해먹는 도박장 절...
# 371224  \n\t\t\t\t\t\t\t\t\t\t\t내가 분명히 힘들 때 대비해서 낸 고용보...
# 371225  \n\t\t\t\t\t\t\t\t\t\t\t메뉴  국민청원 및 제안  최신순  추천...
# 371226  \n\t\t\t\t\t\t\t\t\t\t\t대한민국의   정치가  진정선진화  되려...
# 371227  \n\t\t\t\t\t\t\t\t\t\t\t초중고 12년을 친구들과 같은 나이로 살...
# 371228  \n\t\t\t\t\t\t\t\t\t\t\t대한민국의   정치가  진정선진화  되려...
# 371229  \n\t\t\t\t\t\t\t\t\t\t\t말한마디에 천냥빚을 값는다 라는 말이 있...
#
# [371230 rows x 9 columns]

# %%
def find_int(count):
    i = (re.findall(r'\d+', count))
    ints = int(''.join(map(str, i)))
    return ints

# %%
df["count"] = df["count"].map(find_int)
df
# Out:
#            num     category  start-days    end-days          person progress  \
# 0           21        안전/환경  2017-08-19  2017-11-17     kakao - ***    청원종료
# 1           22           기타  2017-08-19  2017-11-17     kakao - ***    청원종료
# 2           23           미래  2017-08-19  2017-09-03     kakao - ***    청원종료
# 3           24          일자리  2017-08-19  2017-08-26     kakao - ***    청원종료
# 4           25           미래  2017-08-19  2017-09-03     kakao - ***    청원종료
# 5           26         보건복지  2017-08-19  2017-08-26     naver - ***    청원종료
# 6           27         정치개혁  2017-08-19  2017-09-18     naver - ***    청원종료
# 7           28        경제민주화  2017-08-19  2017-08-26     naver - ***    청원종료
# 8           29           미래  2017-08-19  2017-09-18     naver - ***    청원종료
# 9           30          일자리  2017-08-19  2017-11-17     kakao - ***    청원종료
# 10          31         보건복지  2017-08-19  2017-11-17   twitter - ***    청원종료
# 11          32        경제민주화  2017-08-19  2017-09-03     naver - ***    청원종료
# 12          33       인권/성평등  2017-08-19  2017-11-17     naver - ***    청원종료
# 13          34           기타  2017-08-19  2017-09-18     naver - ***    청원종료
# 14          35     외교/통일/국방  2017-08-19  2017-08-26     kakao - ***    청원종료
# 15          36       인권/성평등  2017-08-19  2017-08-26     naver - ***    청원종료
# 16          37           기타  2017-08-19  2017-09-18  facebook - ***    청원종료
# 17          38     외교/통일/국방  2017-08-19  2017-08-26     kakao - ***    청원종료
# 18          40     외교/통일/국방  2017-08-19  2017-09-18     naver - ***    청원종료
# 19          41     외교/통일/국방  2017-08-19  2017-09-18     naver - ***    청원종료
# 20          42        육아/교육  2017-08-19  2017-09-18     naver - ***    청원종료
# 21          43        육아/교육  2017-08-19  2017-09-18     naver - ***    청원종료
# 22          44        육아/교육  2017-08-19  2017-09-18  facebook - ***    청원종료
# 23          45        육아/교육  2017-08-19  2017-11-17  facebook - ***    청원종료
# 24          46        육아/교육  2017-08-19  2017-09-18     naver - ***    청원종료
# 25          47     외교/통일/국방  2017-08-19  2017-09-18  facebook - ***    청원종료
# 26          48  문화/예술/체육/언론  2017-08-19  2017-09-18  facebook - ***    청원종료
# 27          49          일자리  2017-08-19  2017-11-17     naver - ***    청원종료
# 28          50          일자리  2017-08-19  2017-10-18     naver - ***    청원종료
# 29          51        경제민주화  2017-08-19  2017-11-17     naver - ***    청원종료
# ...        ...          ...         ...         ...             ...      ...
# 371200  484310       인권/성평등  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371201  484311     교통/건축/국토  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371202  484312           미래  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371203  484313        안전/환경  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371204  484314        안전/환경  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371205  484315         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371206  484316       인권/성평등  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371207  484317     외교/통일/국방  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371208  484318           기타  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371209  484319     외교/통일/국방  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371210  484320         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371211  484321          일자리  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371212  484322    저출산/고령화대책  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371213  484323       인권/성평등  2019-01-01  2019-01-31  facebook - ***   청원진행중
# 371214  484324     교통/건축/국토  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371215  484325         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371216  484326         정치개혁  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371217  484327           미래  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371218  484328         정치개혁  2019-01-01  2019-01-31  facebook - ***   청원진행중
# 371219  484329         정치개혁  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371220  484330           행정  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371221  484331         정치개혁  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371222  484332       인권/성평등  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371223  484333  문화/예술/체육/언론  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371224  484334          일자리  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371225  484335           미래  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371226  484336         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371227  484337           기타  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371228  484338         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371229  484339         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
#
#                                                     title  count  \
# 0                                     스텔라 데이지호에 대한 제안입니다.      9
# 1                                          비리제보처를 만들어주세요.     17
# 2                                                제2의 개성공단      0
# 3                                공공기관 무조건적인 정규직전환을 반대합니다.     53
# 4                                                제2의 개성공단      0
# 5       보건복지부 부령 제339호중 “특수의료장비 운영에 관한 규칙” 중  불합리한 행정제...      2
# 6                                       김이수 헌재소장 임명 재고 건의      1
# 7                                           소액주주를 보호해주십시오   2137
# 8                                 문재인 정부는 왜 공무원개혁엔 무관심한가?      3
# 9                                     A/S 기사들도 관심을 가져주십시요      1
# 10                     <담배 제조 및 매매금지 법안>을 제정해 주시길 부탁드립니다.      0
# 11                                 소액주주 보호를 위해 조사요청 드립니다.     30
# 12                              납득할 수 있는 장애 재판정을 받고 싶습니다.     15
# 13      『국가유공자 등 예우 및 지원에 관한법률』상「6.25전몰군경 자녀수당」의 불합리한 ...    679
# 14                            문재인정부는 신한국형 페리프로세스가 작성했습니다.      0
# 15          한국채식인구 100만명. 학교 급식 및 군대에서 현미채식 선택권을 보장해주십시오!      1
# 16                                  황우석박사님 연구재개 허용 촉구합니다.    415
# 17                                 한중관계 사드 갈등 해소방법 찾았습니다.      0
# 18                           국가유공자등 예우및 지우너에 관한 법률 시행령 개정    218
# 19                           국가유공자등 예우및 지우너에 관한 법률 시행령 개정    227
# 20                                   기간제 교사의 정규직화를 반대합니다.    173
# 21                                   기간제 교사의 정규직화를 반대합니다.  11293
# 22              해외 수학여행 및 학생 프로그램 참가시 시간외 근무수당을 지급해 주십시오.      9
# 23                                  초등학교 교사 임용 시험 관련 해결방안      0
# 24                                    기간제교사의 정규직화를 반대합니다.   1933
# 25                              국가유공자예우및 지우너에 관한 법률시행령 개정    215
# 26                 3.1 운동 100주년 기념사업 준비, 더이상 지체해서는 안 됩니다.     12
# 27                              공정한사회 절차가 바른사회가 되기를 원합니다.     27
# 28                                 치과위생사 국가고시 날짜 변경 억울합니다   1251
# 29                                     중국기업 국내 상장을 반대합니다.     74
# ...                                                   ...    ...
# 371200         관리자님 (안동경찰의 민간인사찰) 게시글 삭제와 차단에 관하여 말씀 드립니다      1
# 371201                    건설/인테리어 직종 근무시간 및 휴식보장에 힘을 써주세요      2
# 371202                                               줄기세포      0
# 371203                                      정신병자의 계속되는 범죄      1
# 371204       최근 네이버계정이 중화인민공화국 또는 몽골에서 해킹시도가 두 번이나 있었습니다.      0
# 371205                   [개헌건의]공정한 판결을 위해 판사도 선거로 뽑아야합니다.      1
# 371206                                      저의 억울함을 들어주세요      2
# 371207                     병영 내 휴대폰 사용에 대해 다시 한번 생각 해 주세요      2
# 371208         '서기, 양력 VS 단기, 음력' → '만 나이 VS 세는 나이, 연 나이'      3
# 371209                               북한은 핵보유국, 우리는 재앙 보유국      2
# 371210                                      적자국채발행지시 카톡공개      0
# 371211                               누구를 위한 블라인드? 장애인 빼고?      0
# 371212                     국민연금 개선안 - 내 연금이 부모님께 가도록 해주세요      0
# 371213                     반부폐 경찰공무원  김민영의 갑질 억울한 호소문 입니다      0
# 371214                             아파트 불법, 부당행위 와 일부지방공무원      1
# 371215                          투표 한표 저항권을 국민에게 부여해야 합니다.      0
# 371216           [국민감사] 서울고검 박승환 을 직권남용, 국헌문란죄로 고발합니다. 32      0
# 371217                            나라를 더 망치기전에 빨리 탄핵해야합니다.      3
# 371218                                              페미공화국      1
# 371219           [국민감사] 서울고검 박승환 을 직권남용, 국헌문란죄로 고발합니다. 33      0
# 371220                                      공무원연금법에 대한 제언      1
# 371221           [국민감사] 서울고검 박승환 을 직권남용, 국헌문란죄로 고발합니다. 34      0
# 371222                              공정하고 정의로운 나라가 이런 겁니까!      1
# 371223          새해소원은 정의롭게 한게임도박장 철저히 밝혀 정부 연관자들도 조사하는겁니다      1
# 371224                                          자진퇴사 실업급여      1
# 371225  20대-영남-자영업자 "경제정책 잘못"... 전연령대 과반 부정 평가 / 2019년...      1
# 371226                                 국회의원  면책특권을  없애버리자      0
# 371227                            빠른년생들도 친구들과 함께 하고 싶습니다.      1
# 371228                                 국회의원  면책특권을  없애버리자      2
# 371229                                     이해찬 대표님 사퇴하시죠?      0
#
#                                         petition_overview
# 0       \n\t\t\t\t\t\t\t\t\t\t\t스텔라 데이지호에 대한 제안입니다. \n...
# 1       \n\t\t\t\t\t\t\t\t\t\t\t현 정부에 국민들이 가장 원하는 것은 부...
# 2       \n\t\t\t\t\t\t\t\t\t\t\t만일 하시는 대통령님 및 각 부처 장관님...
# 3       \n\t\t\t\t\t\t\t\t\t\t\t현정부에서 정규직 일자리를 늘리는 것에 ...
# 4       \n\t\t\t\t\t\t\t\t\t\t\t만일 하시는 대통령님 및 각 부처 장관님...
# 5       \n\t\t\t\t\t\t\t\t\t\t\t청원인  왕 기 운 \n\t\t\t\t\...
# 6       \n\t\t\t\t\t\t\t\t\t\t\t문 대통령님께 묻습니다 (2017. 8....
# 7       \n\t\t\t\t\t\t\t\t\t\t\t**  존경하옵는 문재인대통령님께  \n...
# 8       \n\t\t\t\t\t\t\t\t\t\t\t살충제 계란 사건으로 국민들을 불안케 하...
# 9       \n\t\t\t\t\t\t\t\t\t\t\t안녕하세요. 저는 LG전자 서비스센터에서...
# 10      \n\t\t\t\t\t\t\t\t\t\t\t안녕하세요 대통령님 \n\t\t\t\t\...
# 11      \n\t\t\t\t\t\t\t\t\t\t\t존경하는 대통령님께,  \n\n\t\t\...
# 12      \n\t\t\t\t\t\t\t\t\t\t\t안녕하십니까? 저는 경직형 양마비 뇌병변...
# 13      \n\t\t\t\t\t\t\t\t\t\t\t(현황) \n\t\t\t\t\t\t\t\...
# 14      \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님 신한국형 페리프로세스 로...
# 15      \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님과 각 정부 인사분들께 마...
# 16      \n\t\t\t\t\t\t\t\t\t\t\t국민의 70% 이상이 황우석박사님을 응원...
# 17      \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님 한중관계 사드 갈등 해소...
# 18      \n\t\t\t\t\t\t\t\t\t\t\t지금부터 67년전 1950년 6.25전쟁...
# 19      \n\t\t\t\t\t\t\t\t\t\t\t지금부터 67년전 1950년 6.25전쟁...
# 20      \n\t\t\t\t\t\t\t\t\t\t\t대통령님, 안녕하세요. 저는 임용을 준비...
# 21      \n\t\t\t\t\t\t\t\t\t\t\t대통령님, 안녕하세요. 저는 임용을 준비...
# 22      \n\t\t\t\t\t\t\t\t\t\t\t광주 과학고등학교에서 학생들을 인솔하여 ...
# 23      \n\t\t\t\t\t\t\t\t\t\t\t초등학교 교사 임용 시험을 수능 시험 처...
# 24      \n\t\t\t\t\t\t\t\t\t\t\t대통령님, 안녕하세요. 저는 임용을 준비...
# 25      \n\t\t\t\t\t\t\t\t\t\t\t지금부터 67년전 1950년 6.25전쟁...
# 26      \n\t\t\t\t\t\t\t\t\t\t\t존경하는 문재인 대통령님, 앞으로 1년 ...
# 27      \n\t\t\t\t\t\t\t\t\t\t\t문재인대통령과 교육부장관님! \n\t\t...
# 28      \n\t\t\t\t\t\t\t\t\t\t\t안녕하십니까? 대통령님 간단하게 제소개 ...
# 29      \n\t\t\t\t\t\t\t\t\t\t\t국내 증시에 상장한 중국 기업들의 현황과...
# ...                                                   ...
# 371200  \n\t\t\t\t\t\t\t\t\t\t\t♣️관리자님 안녕하세요  \n\t\t\t...
# 371201  \n\t\t\t\t\t\t\t\t\t\t\t안녕하세요. 저는 건축/인테리어 업종을 ...
# 371202  \n\t\t\t\t\t\t\t\t\t\t\t줄기세포연구합법화해주세요.전근이완증이라는...
# 371203  \n\t\t\t\t\t\t\t\t\t\t\t누가 새해 첫날부터 이런 글을 쓰고 싶을...
# 371204  \n\t\t\t\t\t\t\t\t\t\t\t인터넷 해킹방지법 만들어주세요! \n\t...
# 371205  \n\t\t\t\t\t\t\t\t\t\t\t결론부터 말하겠습니다. 판사도 투표로 뽑...
# 371206  \n\t\t\t\t\t\t\t\t\t\t\t안녕하세여 저는 일본에서 살다가 2012...
# 371207  \n\t\t\t\t\t\t\t\t\t\t\t올해  2월부터 국방부는 병사들의 일과 ...
# 371208  \n\t\t\t\t\t\t\t\t\t\t\t한국에서는 1962년부터 만 나이를 쓰도...
# 371209  \n\t\t\t\t\t\t\t\t\t\t\t굴욕외교의 결정판 !! \n\t\t\t\...
# 371210  \n\t\t\t\t\t\t\t\t\t\t\t기재부 신재민. 사무관이 적자국채발향지시...
# 371211  \n\t\t\t\t\t\t\t\t\t\t\t제 소개 먼저 하겠습니다. 저는 2014...
# 371212  \n\t\t\t\t\t\t\t\t\t\t\t국민연금 고갈에 대한 이슈가 여전한테 현...
# 371213  \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님 안녕  하십니까.?.. ...
# 371214  \n\t\t\t\t\t\t\t\t\t\t\t청와대 국민청원 \n\n\t\t\t\t\...
# 371215  \n\t\t\t\t\t\t\t\t\t\t\t국민이 자신의  한 표를 투표장에서 행사...
# 371216  \n\t\t\t\t\t\t\t\t\t\t\t사법농단 척결을 위한 후원금 모금안내 1...
# 371217  \n\t\t\t\t\t\t\t\t\t\t\t나라를 더 망치기전에 빨리 탄핵해야합니다...
# 371218  \n\t\t\t\t\t\t\t\t\t\t\t세상ㅇㅣ 이렇게 더럽게 타락한 이유가 멀...
# 371219  \n\t\t\t\t\t\t\t\t\t\t\t사법농단 척결을 위한 후원금 모금안내 1...
# 371220  \n\t\t\t\t\t\t\t\t\t\t\t공무원연금법에 대한 제언 \n\n\t\t...
# 371221  \n\t\t\t\t\t\t\t\t\t\t\t사법농단 척결을 위한 후원금 모금안내 1...
# 371222  \n\t\t\t\t\t\t\t\t\t\t\t돈 없고 힘없는 농민은 언제까지 이렇게 ...
# 371223  \n\t\t\t\t\t\t\t\t\t\t\t지금 이순간에도 대놓고 해먹는 도박장 절...
# 371224  \n\t\t\t\t\t\t\t\t\t\t\t내가 분명히 힘들 때 대비해서 낸 고용보...
# 371225  \n\t\t\t\t\t\t\t\t\t\t\t메뉴  국민청원 및 제안  최신순  추천...
# 371226  \n\t\t\t\t\t\t\t\t\t\t\t대한민국의   정치가  진정선진화  되려...
# 371227  \n\t\t\t\t\t\t\t\t\t\t\t초중고 12년을 친구들과 같은 나이로 살...
# 371228  \n\t\t\t\t\t\t\t\t\t\t\t대한민국의   정치가  진정선진화  되려...
# 371229  \n\t\t\t\t\t\t\t\t\t\t\t말한마디에 천냥빚을 값는다 라는 말이 있...
#
# [371230 rows x 9 columns]

# %%
find_int(df["count"][0])
# Out:
# 9

# %%
df.to_csv("../petition_data_all.csv", index=None)

# %%
df = pd.read_csv("../petition_data_all.csv")

# %%
df
# Out:
#            num     category  start-days    end-days          person progress  \
# 0           21        안전/환경  2017-08-19  2017-11-17     kakao - ***    청원종료
# 1           22           기타  2017-08-19  2017-11-17     kakao - ***    청원종료
# 2           23           미래  2017-08-19  2017-09-03     kakao - ***    청원종료
# 3           24          일자리  2017-08-19  2017-08-26     kakao - ***    청원종료
# 4           25           미래  2017-08-19  2017-09-03     kakao - ***    청원종료
# 5           26         보건복지  2017-08-19  2017-08-26     naver - ***    청원종료
# 6           27         정치개혁  2017-08-19  2017-09-18     naver - ***    청원종료
# 7           28        경제민주화  2017-08-19  2017-08-26     naver - ***    청원종료
# 8           29           미래  2017-08-19  2017-09-18     naver - ***    청원종료
# 9           30          일자리  2017-08-19  2017-11-17     kakao - ***    청원종료
# 10          31         보건복지  2017-08-19  2017-11-17   twitter - ***    청원종료
# 11          32        경제민주화  2017-08-19  2017-09-03     naver - ***    청원종료
# 12          33       인권/성평등  2017-08-19  2017-11-17     naver - ***    청원종료
# 13          34           기타  2017-08-19  2017-09-18     naver - ***    청원종료
# 14          35     외교/통일/국방  2017-08-19  2017-08-26     kakao - ***    청원종료
# 15          36       인권/성평등  2017-08-19  2017-08-26     naver - ***    청원종료
# 16          37           기타  2017-08-19  2017-09-18  facebook - ***    청원종료
# 17          38     외교/통일/국방  2017-08-19  2017-08-26     kakao - ***    청원종료
# 18          40     외교/통일/국방  2017-08-19  2017-09-18     naver - ***    청원종료
# 19          41     외교/통일/국방  2017-08-19  2017-09-18     naver - ***    청원종료
# 20          42        육아/교육  2017-08-19  2017-09-18     naver - ***    청원종료
# 21          43        육아/교육  2017-08-19  2017-09-18     naver - ***    청원종료
# 22          44        육아/교육  2017-08-19  2017-09-18  facebook - ***    청원종료
# 23          45        육아/교육  2017-08-19  2017-11-17  facebook - ***    청원종료
# 24          46        육아/교육  2017-08-19  2017-09-18     naver - ***    청원종료
# 25          47     외교/통일/국방  2017-08-19  2017-09-18  facebook - ***    청원종료
# 26          48  문화/예술/체육/언론  2017-08-19  2017-09-18  facebook - ***    청원종료
# 27          49          일자리  2017-08-19  2017-11-17     naver - ***    청원종료
# 28          50          일자리  2017-08-19  2017-10-18     naver - ***    청원종료
# 29          51        경제민주화  2017-08-19  2017-11-17     naver - ***    청원종료
# ...        ...          ...         ...         ...             ...      ...
# 371200  484310       인권/성평등  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371201  484311     교통/건축/국토  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371202  484312           미래  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371203  484313        안전/환경  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371204  484314        안전/환경  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371205  484315         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371206  484316       인권/성평등  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371207  484317     외교/통일/국방  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371208  484318           기타  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371209  484319     외교/통일/국방  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371210  484320         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371211  484321          일자리  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371212  484322    저출산/고령화대책  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371213  484323       인권/성평등  2019-01-01  2019-01-31  facebook - ***   청원진행중
# 371214  484324     교통/건축/국토  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371215  484325         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371216  484326         정치개혁  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371217  484327           미래  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371218  484328         정치개혁  2019-01-01  2019-01-31  facebook - ***   청원진행중
# 371219  484329         정치개혁  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371220  484330           행정  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371221  484331         정치개혁  2019-01-01  2019-01-31   twitter - ***   청원진행중
# 371222  484332       인권/성평등  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371223  484333  문화/예술/체육/언론  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371224  484334          일자리  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371225  484335           미래  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371226  484336         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371227  484337           기타  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371228  484338         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
# 371229  484339         정치개혁  2019-01-01  2019-01-31     naver - ***   청원진행중
#
#                                                     title  count  \
# 0                                     스텔라 데이지호에 대한 제안입니다.      9
# 1                                          비리제보처를 만들어주세요.     17
# 2                                                제2의 개성공단      0
# 3                                공공기관 무조건적인 정규직전환을 반대합니다.     53
# 4                                                제2의 개성공단      0
# 5       보건복지부 부령 제339호중 “특수의료장비 운영에 관한 규칙” 중  불합리한 행정제...      2
# 6                                       김이수 헌재소장 임명 재고 건의      1
# 7                                           소액주주를 보호해주십시오   2137
# 8                                 문재인 정부는 왜 공무원개혁엔 무관심한가?      3
# 9                                     A/S 기사들도 관심을 가져주십시요      1
# 10                     <담배 제조 및 매매금지 법안>을 제정해 주시길 부탁드립니다.      0
# 11                                 소액주주 보호를 위해 조사요청 드립니다.     30
# 12                              납득할 수 있는 장애 재판정을 받고 싶습니다.     15
# 13      『국가유공자 등 예우 및 지원에 관한법률』상「6.25전몰군경 자녀수당」의 불합리한 ...    679
# 14                            문재인정부는 신한국형 페리프로세스가 작성했습니다.      0
# 15          한국채식인구 100만명. 학교 급식 및 군대에서 현미채식 선택권을 보장해주십시오!      1
# 16                                  황우석박사님 연구재개 허용 촉구합니다.    415
# 17                                 한중관계 사드 갈등 해소방법 찾았습니다.      0
# 18                           국가유공자등 예우및 지우너에 관한 법률 시행령 개정    218
# 19                           국가유공자등 예우및 지우너에 관한 법률 시행령 개정    227
# 20                                   기간제 교사의 정규직화를 반대합니다.    173
# 21                                   기간제 교사의 정규직화를 반대합니다.  11293
# 22              해외 수학여행 및 학생 프로그램 참가시 시간외 근무수당을 지급해 주십시오.      9
# 23                                  초등학교 교사 임용 시험 관련 해결방안      0
# 24                                    기간제교사의 정규직화를 반대합니다.   1933
# 25                              국가유공자예우및 지우너에 관한 법률시행령 개정    215
# 26                 3.1 운동 100주년 기념사업 준비, 더이상 지체해서는 안 됩니다.     12
# 27                              공정한사회 절차가 바른사회가 되기를 원합니다.     27
# 28                                 치과위생사 국가고시 날짜 변경 억울합니다   1251
# 29                                     중국기업 국내 상장을 반대합니다.     74
# ...                                                   ...    ...
# 371200         관리자님 (안동경찰의 민간인사찰) 게시글 삭제와 차단에 관하여 말씀 드립니다      1
# 371201                    건설/인테리어 직종 근무시간 및 휴식보장에 힘을 써주세요      2
# 371202                                               줄기세포      0
# 371203                                      정신병자의 계속되는 범죄      1
# 371204       최근 네이버계정이 중화인민공화국 또는 몽골에서 해킹시도가 두 번이나 있었습니다.      0
# 371205                   [개헌건의]공정한 판결을 위해 판사도 선거로 뽑아야합니다.      1
# 371206                                      저의 억울함을 들어주세요      2
# 371207                     병영 내 휴대폰 사용에 대해 다시 한번 생각 해 주세요      2
# 371208         '서기, 양력 VS 단기, 음력' → '만 나이 VS 세는 나이, 연 나이'      3
# 371209                               북한은 핵보유국, 우리는 재앙 보유국      2
# 371210                                      적자국채발행지시 카톡공개      0
# 371211                               누구를 위한 블라인드? 장애인 빼고?      0
# 371212                     국민연금 개선안 - 내 연금이 부모님께 가도록 해주세요      0
# 371213                     반부폐 경찰공무원  김민영의 갑질 억울한 호소문 입니다      0
# 371214                             아파트 불법, 부당행위 와 일부지방공무원      1
# 371215                          투표 한표 저항권을 국민에게 부여해야 합니다.      0
# 371216           [국민감사] 서울고검 박승환 을 직권남용, 국헌문란죄로 고발합니다. 32      0
# 371217                            나라를 더 망치기전에 빨리 탄핵해야합니다.      3
# 371218                                              페미공화국      1
# 371219           [국민감사] 서울고검 박승환 을 직권남용, 국헌문란죄로 고발합니다. 33      0
# 371220                                      공무원연금법에 대한 제언      1
# 371221           [국민감사] 서울고검 박승환 을 직권남용, 국헌문란죄로 고발합니다. 34      0
# 371222                              공정하고 정의로운 나라가 이런 겁니까!      1
# 371223          새해소원은 정의롭게 한게임도박장 철저히 밝혀 정부 연관자들도 조사하는겁니다      1
# 371224                                          자진퇴사 실업급여      1
# 371225  20대-영남-자영업자 "경제정책 잘못"... 전연령대 과반 부정 평가 / 2019년...      1
# 371226                                 국회의원  면책특권을  없애버리자      0
# 371227                            빠른년생들도 친구들과 함께 하고 싶습니다.      1
# 371228                                 국회의원  면책특권을  없애버리자      2
# 371229                                     이해찬 대표님 사퇴하시죠?      0
#
#                                         petition_overview
# 0       \n\t\t\t\t\t\t\t\t\t\t\t스텔라 데이지호에 대한 제안입니다. \n...
# 1       \n\t\t\t\t\t\t\t\t\t\t\t현 정부에 국민들이 가장 원하는 것은 부...
# 2       \n\t\t\t\t\t\t\t\t\t\t\t만일 하시는 대통령님 및 각 부처 장관님...
# 3       \n\t\t\t\t\t\t\t\t\t\t\t현정부에서 정규직 일자리를 늘리는 것에 ...
# 4       \n\t\t\t\t\t\t\t\t\t\t\t만일 하시는 대통령님 및 각 부처 장관님...
# 5       \n\t\t\t\t\t\t\t\t\t\t\t청원인  왕 기 운 \n\t\t\t\t\...
# 6       \n\t\t\t\t\t\t\t\t\t\t\t문 대통령님께 묻습니다 (2017. 8....
# 7       \n\t\t\t\t\t\t\t\t\t\t\t**  존경하옵는 문재인대통령님께  \n...
# 8       \n\t\t\t\t\t\t\t\t\t\t\t살충제 계란 사건으로 국민들을 불안케 하...
# 9       \n\t\t\t\t\t\t\t\t\t\t\t안녕하세요. 저는 LG전자 서비스센터에서...
# 10      \n\t\t\t\t\t\t\t\t\t\t\t안녕하세요 대통령님 \n\t\t\t\t\...
# 11      \n\t\t\t\t\t\t\t\t\t\t\t존경하는 대통령님께,  \n\n\t\t\...
# 12      \n\t\t\t\t\t\t\t\t\t\t\t안녕하십니까? 저는 경직형 양마비 뇌병변...
# 13      \n\t\t\t\t\t\t\t\t\t\t\t(현황) \n\t\t\t\t\t\t\t\...
# 14      \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님 신한국형 페리프로세스 로...
# 15      \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님과 각 정부 인사분들께 마...
# 16      \n\t\t\t\t\t\t\t\t\t\t\t국민의 70% 이상이 황우석박사님을 응원...
# 17      \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님 한중관계 사드 갈등 해소...
# 18      \n\t\t\t\t\t\t\t\t\t\t\t지금부터 67년전 1950년 6.25전쟁...
# 19      \n\t\t\t\t\t\t\t\t\t\t\t지금부터 67년전 1950년 6.25전쟁...
# 20      \n\t\t\t\t\t\t\t\t\t\t\t대통령님, 안녕하세요. 저는 임용을 준비...
# 21      \n\t\t\t\t\t\t\t\t\t\t\t대통령님, 안녕하세요. 저는 임용을 준비...
# 22      \n\t\t\t\t\t\t\t\t\t\t\t광주 과학고등학교에서 학생들을 인솔하여 ...
# 23      \n\t\t\t\t\t\t\t\t\t\t\t초등학교 교사 임용 시험을 수능 시험 처...
# 24      \n\t\t\t\t\t\t\t\t\t\t\t대통령님, 안녕하세요. 저는 임용을 준비...
# 25      \n\t\t\t\t\t\t\t\t\t\t\t지금부터 67년전 1950년 6.25전쟁...
# 26      \n\t\t\t\t\t\t\t\t\t\t\t존경하는 문재인 대통령님, 앞으로 1년 ...
# 27      \n\t\t\t\t\t\t\t\t\t\t\t문재인대통령과 교육부장관님! \n\t\t...
# 28      \n\t\t\t\t\t\t\t\t\t\t\t안녕하십니까? 대통령님 간단하게 제소개 ...
# 29      \n\t\t\t\t\t\t\t\t\t\t\t국내 증시에 상장한 중국 기업들의 현황과...
# ...                                                   ...
# 371200  \n\t\t\t\t\t\t\t\t\t\t\t♣️관리자님 안녕하세요  \n\t\t\t...
# 371201  \n\t\t\t\t\t\t\t\t\t\t\t안녕하세요. 저는 건축/인테리어 업종을 ...
# 371202  \n\t\t\t\t\t\t\t\t\t\t\t줄기세포연구합법화해주세요.전근이완증이라는...
# 371203  \n\t\t\t\t\t\t\t\t\t\t\t누가 새해 첫날부터 이런 글을 쓰고 싶을...
# 371204  \n\t\t\t\t\t\t\t\t\t\t\t인터넷 해킹방지법 만들어주세요! \n\t...
# 371205  \n\t\t\t\t\t\t\t\t\t\t\t결론부터 말하겠습니다. 판사도 투표로 뽑...
# 371206  \n\t\t\t\t\t\t\t\t\t\t\t안녕하세여 저는 일본에서 살다가 2012...
# 371207  \n\t\t\t\t\t\t\t\t\t\t\t올해  2월부터 국방부는 병사들의 일과 ...
# 371208  \n\t\t\t\t\t\t\t\t\t\t\t한국에서는 1962년부터 만 나이를 쓰도...
# 371209  \n\t\t\t\t\t\t\t\t\t\t\t굴욕외교의 결정판 !! \n\t\t\t\...
# 371210  \n\t\t\t\t\t\t\t\t\t\t\t기재부 신재민. 사무관이 적자국채발향지시...
# 371211  \n\t\t\t\t\t\t\t\t\t\t\t제 소개 먼저 하겠습니다. 저는 2014...
# 371212  \n\t\t\t\t\t\t\t\t\t\t\t국민연금 고갈에 대한 이슈가 여전한테 현...
# 371213  \n\t\t\t\t\t\t\t\t\t\t\t문재인 대통령님 안녕  하십니까.?.. ...
# 371214  \n\t\t\t\t\t\t\t\t\t\t\t청와대 국민청원 \n\n\t\t\t\t\...
# 371215  \n\t\t\t\t\t\t\t\t\t\t\t국민이 자신의  한 표를 투표장에서 행사...
# 371216  \n\t\t\t\t\t\t\t\t\t\t\t사법농단 척결을 위한 후원금 모금안내 1...
# 371217  \n\t\t\t\t\t\t\t\t\t\t\t나라를 더 망치기전에 빨리 탄핵해야합니다...
# 371218  \n\t\t\t\t\t\t\t\t\t\t\t세상ㅇㅣ 이렇게 더럽게 타락한 이유가 멀...
# 371219  \n\t\t\t\t\t\t\t\t\t\t\t사법농단 척결을 위한 후원금 모금안내 1...
# 371220  \n\t\t\t\t\t\t\t\t\t\t\t공무원연금법에 대한 제언 \n\n\t\t...
# 371221  \n\t\t\t\t\t\t\t\t\t\t\t사법농단 척결을 위한 후원금 모금안내 1...
# 371222  \n\t\t\t\t\t\t\t\t\t\t\t돈 없고 힘없는 농민은 언제까지 이렇게 ...
# 371223  \n\t\t\t\t\t\t\t\t\t\t\t지금 이순간에도 대놓고 해먹는 도박장 절...
# 371224  \n\t\t\t\t\t\t\t\t\t\t\t내가 분명히 힘들 때 대비해서 낸 고용보...
# 371225  \n\t\t\t\t\t\t\t\t\t\t\t메뉴  국민청원 및 제안  최신순  추천...
# 371226  \n\t\t\t\t\t\t\t\t\t\t\t대한민국의   정치가  진정선진화  되려...
# 371227  \n\t\t\t\t\t\t\t\t\t\t\t초중고 12년을 친구들과 같은 나이로 살...
# 371228  \n\t\t\t\t\t\t\t\t\t\t\t대한민국의   정치가  진정선진화  되려...
# 371229  \n\t\t\t\t\t\t\t\t\t\t\t말한마디에 천냥빚을 값는다 라는 말이 있...
#
# [371230 rows x 9 columns]

# %%
datas = [1785,
 10949,
 18278,
 26024,
 45581,
 49083,
 57132,
 76020,
 79162,
 81026,
 95138,
 96427,
 101349,
 105105,
 113699,
 127921,
 134590,
 141333,
 142600,
 148613,
 148806,
 151430,
 157046,
 164255,
 165796,
 173355,
 174292,
 178781,
 187633,
 199622,
 199778,
 201953,
 203181,
 219348,
 230552,
 231701,
 235102,
 236397,
 242950,
 244045,
 246489,
 269548,
 270921,
 272632,
 273112,
 281200,
 282903,
 284845,
 294226,
 314584,
 322420,
 369690,
 384676,
 395955,
 397558,
 398030,
 408609,
 410447,
 411485,
 412722,
 414891,
 417147,
 418376,
 426349,
 426834,
 436901,
 442093,
 446686]

# %%
def FindPetition(num):
    global kr, other
    url = "https://www1.president.go.kr/petitions/"
    url = url + str(num)
    try:
        html = urlopen(url)
    except urllib.error.HTTPError as e:
        print(e)
        print("=============error %d ============="%num)
    else:
        try:
            bsObj = BeautifulSoup(html.read(), "html.parser")
        except urllib.exceptions.SSLError as e:
            print(e)
            print("=============error %d ============="%num)
        else:
            #print("============%d===================" % num)
            progress = bsObj.find("div",{"class":"petitionsView_progress"}).get_text()
            title = bsObj.find("h3",{"class":"petitionsView_title"}).get_text()
            count = bsObj.find("h2",{"class":"petitionsView_count"}).get_text()
            petition_overview = bsObj.find("div",{"class":"View_write"}).get_text()
            days = bsObj.find("ul",{"class":"petitionsView_info_list"}).get_text()
            days = days.split("\n")
            category = days[1]
            sdays = days[2]
            edays = days[3]
            person = days[4]
            if(num%1000==0):
                print(num)
            #print("1. 청원 현황 : ", progress)
            #print("2. 청원 제목 : ",title)
            #print("3. 청원 참가자 수 : ",count)
            #print("4. 청원 내용 : ",petition_overview)
            
            try:
                days = str(days[4:])
                progress = str(progress[1:])
                title = str(title)
                count = str(count)
                petition_overview = str(petition_overview)
                category = str(category[4:])
                sdays = str(sdays[4:])
                edays = str(edays[4:])
                person = str(person[3:])
                
                #print(category,sdays,edays,person)
            except:
                print("=============error %d ============="%num)
            else:
                csvRow = []
                csvRow.extend([num,category,sdays,edays,person,progress,title,count,petition_overview])
                writer.writerow(csvRow)

# %%
csvFile = open("briefing.csv", 'w', encoding='UTF-8')
writer = csv.writer(csvFile)
writer.writerow(["num","category","start-days","end-days","person","progress","title","count","petition_overview","petition_answer"])
for i in datas:
    FindPetition(i)
csvFile.close()
# Out:
# -----------------------------------------------------------
# NameError                 Traceback (most recent call last)
# <ipython-input-7-60d8ca4bcc2a> in <module>
#       1 csvFile = open("briefing.csv", 'w', encoding='UTF-8')
# ----> 2 writer = csv.writer(csvFile)
#       3 writer.writerow(["num","category","start-days","end-days","person","progress","title","count","petition_overview","petition_answer"])
#       4 for i in datas:
#       5     FindPetition(i)
#
# NameError: name 'csv' is not defined
